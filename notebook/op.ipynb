# %%
# %%capture
# !pip install openai

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("api_key_qroq")
client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1"
    )

# %%
response = client.chat.completions.create(
    model='openai/gpt-oss-120b',
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write a poem about the beauty of nature."}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# **Whispers of the Wild**
#
# In the hush of morning’s first soft sigh,
# A golden thread pulls night’s dark veil—
# Sunlight spills across the trembling sky,
# And paints the world in amber pale.
#
# Leaves unfurl like emerald fans,
# Their veins a map of hidden rivers,
# Each breath a hymn the forest sings,
# A chorus where the silence shivers.
#
# Mountains rise, ancient stone and snow,
# Their shoulders crowned with clouds that roam,
# They hold the sky in quiet repose,
# A steadfast heart, a stone‑bound home.
#
# Rivers carve their silver lines,
# Through valleys wide and narrow clefts,
# Their murmurs tell of endless time,
# Of journeys born in mist‑kissed depths.
#
# The meadow blooms in riotous hue—
# Wildflowers whisper, “Here we stand,”
# Their petals catch the wandering dew,
# And scatter joy across the land.
#
# Night descends with velvet shade,
# Stars ignite the vaulted dome,
# The moon, a silver lantern swayed,
# Guides the tide, the night‑bird’s home.
#
# All of this breathes, a living lace,
# Woven through the pulse of earth,
# In every wind, in every place—
# Nature’s beauty sings its birth.

# %%
client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1"
    )
response = client.chat.completions.create(
    model='openai/gpt-oss-120b',
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write a poem about the beauty of nature."}
    ]
)
# Out:
# CompletionUsage(completion_tokens=293, prompt_tokens=89, total_tokens=382, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=24, rejected_prediction_tokens=None, text_tokens=None), prompt_tokens_details=None, queue_time=0.157747455, prompt_time=0.0142423, completion_time=0.615649374, total_time=0.629891674)
